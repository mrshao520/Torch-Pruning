# %% [markdown]
# # Quick Start

# %% [markdown]
# In this part, we provide some basic yet all-in-one examples to show the features of Torch-Pruning.

# %%
import warnings
warnings.filterwarnings('ignore')
import sys, os
sys.path.append(os.path.abspath("../"))

import torch
from torchvision.models import resnet18
import torch_pruning as tp

# %% [markdown]
# ### Method 1. Pruning with DepGraph
#
# ``DependencyGraph`` serves as the cornerstone of Torch-Pruning, which automatically identifies and groups all layers with inter-dependency. In structural pruning, two layers with dependency should be pruned simultaneously. Therefore, to prune a complicated model, we need to handle those layers carefully. The following example shows the pipeline of pruning single layer in a ResNet-18.

# %%
# 0. prepare your model and example inputs
model = resnet18(pretrained=True).eval()
example_inputs = torch.randn(1,3,224,224)

# 1. build dependency graph for resnet18
# 构建依赖关系图
DG = tp.DependencyGraph().build_dependency(model, example_inputs=example_inputs)

# 2. Select some channels to prune. Here we prune the channels indexed by [2, 6, 9].
# 修剪 conv1 的输出通道，修剪函数，修剪通道索引
pruning_idxs = pruning_idxs=[2, 6, 9]
pruning_group = DG.get_pruning_group( model.conv1, tp.prune_conv_out_channels, idxs=pruning_idxs )

# 3. prune all grouped layer that is coupled with model.conv1
# 修剪
if DG.check_pruning_group(pruning_group):
    pruning_group.prune()

# %% [markdown]
# After invoking the ``.exec`` method, an inplace pruning will be applied to the model. Upon printing the model, we can notice that multiple layers, such as "model.conv1", "model.bn1", and "model.layer1[0].conv1" are pruned by Torch-Pruning.

# %%
print("After pruning:")
print(model)
# Out:
# After pruning:
# ResNet(
#   (conv1): Conv2d(3, 61, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(61, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(61, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 61, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(61, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(61, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 61, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(61, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(61, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(61, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=1000, bias=True)
# )

# %% [markdown]
# Let's inspect the pruning group. The results will show how a pruning operation triggers (=>) another one.

# %%
print(pruning_group)
# Out:
# --------------------------------
#           Pruning Group
# --------------------------------
# [0] prune_out_channels on conv1 (Conv2d(3, 61, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)) => prune_out_channels on conv1 (Conv2d(3, 61, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)), len(idxs)=3
# [1] prune_out_channels on conv1 (Conv2d(3, 61, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)) => prune_out_channels on bn1 (BatchNorm2d(61, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)), len(idxs)=3
# [2] prune_out_channels on bn1 (BatchNorm2d(61, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)) => prune_out_channels on _ElementWiseOp_20(ReluBackward0), len(idxs)=3
# [3] prune_out_channels on _ElementWiseOp_20(ReluBackward0) => prune_out_channels on _ElementWiseOp_19(MaxPool2DWithIndicesBackward0), len(idxs)=3
# [4] prune_out_channels on _ElementWiseOp_19(MaxPool2DWithIndicesBackward0) => prune_out_channels on _ElementWiseOp_18(AddBackward0), len(idxs)=3
# [5] prune_out_channels on _ElementWiseOp_19(MaxPool2DWithIndicesBackward0) => prune_in_channels on layer1.0.conv1 (Conv2d(61, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=3
# [6] prune_out_channels on _ElementWiseOp_18(AddBackward0) => prune_out_channels on layer1.0.bn2 (BatchNorm2d(61, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)), len(idxs)=3
# [7] prune_out_channels on _ElementWiseOp_18(AddBackward0) => prune_out_channels on _ElementWiseOp_17(ReluBackward0), len(idxs)=3
# [8] prune_out_channels on _ElementWiseOp_17(ReluBackward0) => prune_out_channels on _ElementWiseOp_16(AddBackward0), len(idxs)=3
# [9] prune_out_channels on _ElementWiseOp_17(ReluBackward0) => prune_in_channels on layer1.1.conv1 (Conv2d(61, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=3
# [10] prune_out_channels on _ElementWiseOp_16(AddBackward0) => prune_out_channels on layer1.1.bn2 (BatchNorm2d(61, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)), len(idxs)=3
# [11] prune_out_channels on _ElementWiseOp_16(AddBackward0) => prune_out_channels on _ElementWiseOp_15(ReluBackward0), len(idxs)=3
# [12] prune_out_channels on _ElementWiseOp_15(ReluBackward0) => prune_in_channels on layer2.0.downsample.0 (Conv2d(61, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)), len(idxs)=3
# [13] prune_out_channels on _ElementWiseOp_15(ReluBackward0) => prune_in_channels on layer2.0.conv1 (Conv2d(61, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)), len(idxs)=3
# [14] prune_out_channels on layer1.1.bn2 (BatchNorm2d(61, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)) => prune_out_channels on layer1.1.conv2 (Conv2d(64, 61, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=3
# [15] prune_out_channels on layer1.0.bn2 (BatchNorm2d(61, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)) => prune_out_channels on layer1.0.conv2 (Conv2d(64, 61, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=3
# --------------------------------

# %% [markdown]
# You can also get all groups from ``DependencyGraph`` using the ``get_all_groups`` method.

# %%
all_groups = list(DG.get_all_groups())
print("Number of Groups: %d"%len(all_groups))
print(f"The first Group: {all_groups[0]}")
print("The last Group:", all_groups[-1])
# Out:
# Number of Groups: 13
# The first Group:
# --------------------------------
#           Pruning Group
# --------------------------------
# [0] prune_out_channels on fc (Linear(in_features=512, out_features=1000, bias=True)) => prune_out_channels on fc (Linear(in_features=512, out_features=1000, bias=True)), len(idxs)=1000
# --------------------------------
#
# The last Group:
# --------------------------------
#           Pruning Group
# --------------------------------
# [0] prune_out_channels on layer4.1.conv1 (Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)) => prune_out_channels on layer4.1.conv1 (Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=512
# [1] prune_out_channels on layer4.1.conv1 (Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)) => prune_out_channels on layer4.1.bn1 (BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)), len(idxs)=512
# [2] prune_out_channels on layer4.1.bn1 (BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)) => prune_out_channels on _ElementWiseOp_28(ReluBackward0), len(idxs)=512
# [3] prune_out_channels on _ElementWiseOp_28(ReluBackward0) => prune_in_channels on layer4.1.conv2 (Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=512
# --------------------------------

# %% [markdown]
# 如何扫描所有组（高级）：
# 一个模型中可能有多个组。我们可以使用 DG.get_all_groups(ignored_layers, root_module_types) 按顺序扫描所有可剪枝的组。每个组将从与 root_module_types 中的 nn.Module 类匹配的层开始。 ignored_layers 参数用于跳过一些不应被剪枝的层。例如，我们可以跳过 ResNet 模型中的第一个卷积层。

# %%
for group in DG.get_all_groups(ignored_layers=[model.conv1], root_module_types=[torch.nn.Conv2d, torch.nn.Linear]):
    # 按顺序处理组
    idxs = [2, 4, 6]
    group.prune(idxs=idxs)
    print(group)
# Out:
# --------------------------------
#           Pruning Group
# --------------------------------
# [0] prune_out_channels on fc (Linear(in_features=-12, out_features=-9, bias=True)) => prune_out_channels on fc (Linear(in_features=-12, out_features=-9, bias=True)), len(idxs)=0
# --------------------------------
#
#
# --------------------------------
#           Pruning Group
# --------------------------------
# [0] prune_out_channels on layer4.0.downsample.0 (Conv2d(-12, -15, kernel_size=(1, 1), stride=(2, 2), bias=False)) => prune_out_channels on layer4.0.downsample.0 (Conv2d(-12, -15, kernel_size=(1, 1), stride=(2, 2), bias=False)), len(idxs)=0
# --------------------------------
#
#
# --------------------------------
#           Pruning Group
# --------------------------------
# [0] prune_out_channels on layer3.0.downsample.0 (Conv2d(-12, -15, kernel_size=(1, 1), stride=(2, 2), bias=False)) => prune_out_channels on layer3.0.downsample.0 (Conv2d(-12, -15, kernel_size=(1, 1), stride=(2, 2), bias=False)), len(idxs)=0
# --------------------------------
#
#
# --------------------------------
#           Pruning Group
# --------------------------------
# [0] prune_out_channels on layer2.0.downsample.0 (Conv2d(61, -15, kernel_size=(1, 1), stride=(2, 2), bias=False)) => prune_out_channels on layer2.0.downsample.0 (Conv2d(61, -15, kernel_size=(1, 1), stride=(2, 2), bias=False)), len(idxs)=0
# --------------------------------
#
#
# --------------------------------
#           Pruning Group
# --------------------------------
# [0] prune_out_channels on layer1.0.conv1 (Conv2d(61, -9, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)) => prune_out_channels on layer1.0.conv1 (Conv2d(61, -9, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=0
# --------------------------------
#
#
# --------------------------------
#           Pruning Group
# --------------------------------
# [0] prune_out_channels on layer1.1.conv1 (Conv2d(61, -9, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)) => prune_out_channels on layer1.1.conv1 (Conv2d(61, -9, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=0
# --------------------------------
#
#
# --------------------------------
#           Pruning Group
# --------------------------------
# [0] prune_out_channels on layer2.0.conv2 (Conv2d(-6, -18, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)) => prune_out_channels on layer2.0.conv2 (Conv2d(-6, -18, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=0
# --------------------------------
#
#
# --------------------------------
#           Pruning Group
# --------------------------------
# [0] prune_out_channels on layer2.0.conv1 (Conv2d(61, -9, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)) => prune_out_channels on layer2.0.conv1 (Conv2d(61, -9, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)), len(idxs)=0
# --------------------------------
#
#
# --------------------------------
#           Pruning Group
# --------------------------------
# [0] prune_out_channels on layer2.1.conv2 (Conv2d(-6, -21, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)) => prune_out_channels on layer2.1.conv2 (Conv2d(-6, -21, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=0
# --------------------------------
#
#
# --------------------------------
#           Pruning Group
# --------------------------------
# [0] prune_out_channels on layer2.1.conv1 (Conv2d(-21, -9, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)) => prune_out_channels on layer2.1.conv1 (Conv2d(-21, -9, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=0
# --------------------------------
#
#
# --------------------------------
#           Pruning Group
# --------------------------------
# [0] prune_out_channels on layer3.0.conv2 (Conv2d(-6, -18, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)) => prune_out_channels on layer3.0.conv2 (Conv2d(-6, -18, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=0
# --------------------------------
#
#
# --------------------------------
#           Pruning Group
# --------------------------------
# [0] prune_out_channels on layer3.0.conv1 (Conv2d(-21, -9, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)) => prune_out_channels on layer3.0.conv1 (Conv2d(-21, -9, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)), len(idxs)=0
# --------------------------------
#
#
# --------------------------------
#           Pruning Group
# --------------------------------
# [0] prune_out_channels on layer3.1.conv2 (Conv2d(-6, -21, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)) => prune_out_channels on layer3.1.conv2 (Conv2d(-6, -21, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=0
# --------------------------------
#
#
# --------------------------------
#           Pruning Group
# --------------------------------
# [0] prune_out_channels on layer3.1.conv1 (Conv2d(-21, -9, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)) => prune_out_channels on layer3.1.conv1 (Conv2d(-21, -9, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=0
# --------------------------------
#
#
# --------------------------------
#           Pruning Group
# --------------------------------
# [0] prune_out_channels on layer4.0.conv2 (Conv2d(-6, -18, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)) => prune_out_channels on layer4.0.conv2 (Conv2d(-6, -18, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=0
# --------------------------------
#
#
# --------------------------------
#           Pruning Group
# --------------------------------
# [0] prune_out_channels on layer4.0.conv1 (Conv2d(-21, -9, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)) => prune_out_channels on layer4.0.conv1 (Conv2d(-21, -9, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)), len(idxs)=0
# --------------------------------
#
#
# --------------------------------
#           Pruning Group
# --------------------------------
# [0] prune_out_channels on layer4.1.conv2 (Conv2d(-6, -21, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)) => prune_out_channels on layer4.1.conv2 (Conv2d(-6, -21, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=0
# --------------------------------
#
#
# --------------------------------
#           Pruning Group
# --------------------------------
# [0] prune_out_channels on layer4.1.conv1 (Conv2d(-21, -9, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)) => prune_out_channels on layer4.1.conv1 (Conv2d(-21, -9, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=0
# --------------------------------

# %% [markdown]
# ---

# %% [markdown]
# ### 2. High-level Pruners
#
# Pruning a neural network using the ``DependencyGraph`` can be still complicated, especially for models with numerous layers. Therefore, we also offer high-level pruners to simplify this process. For example, you can easily prune a ResNet18 model with a simple magnitude-based pruner. This method removes weights with small magnitude in the network, resulting in a smaller and faster model without too much performance lost in accuracy
#
# 通过 DepGraph，我们开发了几个高级剪枝工具来简化剪枝过程。通过指定所需的通道剪枝比例，剪枝工具将扫描所有可剪枝的组，估计权重重要性并执行剪枝。您可以使用自己的训练代码微调剩余的权重。有关此过程的详细信息，请参阅本教程，该教程展示了如何从头实现 Network Slimming（ICCV 2017）剪枝工具。此外，VainF/Isomorphic-Pruning 中提供了 ViT 和 ConvNext 剪枝的更实用示例。

# %%
model = resnet18(pretrained=True)
example_inputs = torch.randn(1, 3, 224, 224)

# 0. importance criterion for parameter selections
# 重要性准则，在这里我们计算分组权重的 L2 范数作为重要性评分。
imp = tp.importance.MagnitudeImportance(p=2, group_reduction="mean")

# 1. ignore some layers that should not be pruned, e.g., the final classifier layer.
ignored_layers = []
for name, module in model.named_modules():
    if isinstance(module, torch.nn.Linear) and module.out_features == 1000:
        ignored_layers.append(module)  # DO NOT prune the final classifier!
        print(name)

# 2. Pruner initialization
# 剪枝初始化
iterative_steps = 5  # You can prune your model to the target pruning ratio iteratively.
pruner = tp.pruner.MagnitudePruner(
    model,
    example_inputs,
    isomorphic=True,
    global_pruning=True,  # If False, a uniform ratio will be assigned to different layers.
    importance=imp,  # importance criterion for parameter selection
    iterative_steps=iterative_steps,  # the number of iterations to achieve target ratio
    pruning_ratio=0.5,  # remove 50% channels, ResNet18 = {64, 128, 256, 512} => ResNet18_Half = {32, 64, 128, 256}
    ignored_layers=ignored_layers,
    pruning_ratio_dict={
        model.conv1: 0.2,
    },
)

base_macs, base_nparams = tp.utils.count_ops_and_params(model, example_inputs)
for i in range(iterative_steps):
    # 3. the pruner.step will remove some channels from the model with least importance
    # tp.utils.print_tool.before_pruning(model)
    pruner.step()
    # tp.utils.print_tool.after_pruning(model)

    # 4. Do whatever you like here, such as fintuning
    macs, nparams = tp.utils.count_ops_and_params(model, example_inputs)
    # print(model)
    print(model(example_inputs).shape)
    print(
        "  Iter %d/%d, Params: %.2f M => %.2f M"
        % (i + 1, iterative_steps, base_nparams / 1e6, nparams / 1e6)
    )
    print(
        "  Iter %d/%d, MACs: %.2f G => %.2f G"
        % (i + 1, iterative_steps, base_macs / 1e9, macs / 1e9)
    )
    # finetune your model here
    # finetune(model)
    # ...

print(model)
# Out:
# fc
# torch.Size([1, 1000])
#   Iter 1/5, Params: 11.69 M => 9.98 M
#   Iter 1/5, MACs: 1.82 G => 1.37 G
# torch.Size([1, 1000])
#   Iter 2/5, Params: 11.69 M => 8.32 M
#   Iter 2/5, MACs: 1.82 G => 1.03 G
# torch.Size([1, 1000])
#   Iter 3/5, Params: 11.69 M => 6.72 M
#   Iter 3/5, MACs: 1.82 G => 0.76 G
# torch.Size([1, 1000])
#   Iter 4/5, Params: 11.69 M => 5.22 M
#   Iter 4/5, MACs: 1.82 G => 0.54 G
# torch.Size([1, 1000])
#   Iter 5/5, Params: 11.69 M => 3.85 M
#   Iter 5/5, MACs: 1.82 G => 0.38 G
# ResNet(
#   (conv1): Conv2d(3, 51, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(51, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(51, 6, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(6, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(6, 51, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(51, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(51, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(3, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(3, 51, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(51, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(51, 45, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(45, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(45, 37, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(37, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(51, 37, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(37, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(37, 31, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(31, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(31, 37, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(37, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(37, 33, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(33, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(33, 155, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(155, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(37, 155, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(155, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(155, 78, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(78, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(78, 155, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(155, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(155, 355, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(355, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(355, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(155, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 409, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(409, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(409, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=256, out_features=1000, bias=True)
# )

# %% [markdown]
# ### 交互式剪枝
#
# 所有高级剪枝器都提供交互式剪枝支持。您可以使用方法 pruner.step(interactive=True) 获取所有组，并通过调用 group.prune() 交互式地剪枝。如果需要控制或监控剪枝过程，此功能特别有用。

# %%
model = resnet18(pretrained=True)
example_inputs = torch.randn(1, 3, 224, 224)

# 0. importance criterion for parameter selections
# 重要性准则，在这里我们计算分组权重的 L2 范数作为重要性评分。
imp = tp.importance.MagnitudeImportance(p=2, group_reduction="mean")

# 1. ignore some layers that should not be pruned, e.g., the final classifier layer.
ignored_layers = []
for name, module in model.named_modules():
    if isinstance(module, torch.nn.Linear) and module.out_features == 1000:
        ignored_layers.append(module)  # DO NOT prune the final classifier!
        print(name)

# 2. Pruner initialization
# 剪枝初始化
iterative_steps = 5  # You can prune your model to the target pruning ratio iteratively.
pruner = tp.pruner.MagnitudePruner(
    model,
    example_inputs,
    isomorphic=True,
    global_pruning=True,  # If False, a uniform ratio will be assigned to different layers.
    importance=imp,  # importance criterion for parameter selection
    iterative_steps=iterative_steps,  # the number of iterations to achieve target ratio
    pruning_ratio=0.5,  # remove 50% channels, ResNet18 = {64, 128, 256, 512} => ResNet18_Half = {32, 64, 128, 256}
    ignored_layers=ignored_layers,
    pruning_ratio_dict={
        model.conv1: 0.2,
    },
)

base_macs, base_nparams = tp.utils.count_ops_and_params(model, example_inputs)
for i in range(iterative_steps):
    for group in pruner.step(interactive=True):
        print(group)
        # get the indxs
        dep, idxs = group[0]
        # get the root module
        target_model = dep.target.module 
        # get the pruning function
        pruning_fn = dep.handler
        
        print(dep)
        print(idxs)
        print(target_model)
        print(pruning_fn)
        
        group.prune()
        # group.prune(idxs=[0, 2, 6]) # It is even possible to change the pruning behaviour with the idxs parameter
    
    # 4. Do whatever you like here, such as fintuning
    macs, nparams = tp.utils.count_ops_and_params(model, example_inputs)
    # print(model)
    print(model(example_inputs).shape)
    print(
        "  Iter %d/%d, Params: %.2f M => %.2f M"
        % (i + 1, iterative_steps, base_nparams / 1e6, nparams / 1e6)
    )
    print(
        "  Iter %d/%d, MACs: %.2f G => %.2f G"
        % (i + 1, iterative_steps, base_macs / 1e9, macs / 1e9)
    )
    # finetune your model here
    # finetune(model)
    # ...

# print(model)
# Out:
# fc
#
# --------------------------------
#           Pruning Group
# --------------------------------
# [0] prune_out_channels on layer4.0.downsample.0 (Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)) => prune_out_channels on layer4.0.downsample.0 (Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)), len(idxs)=52
# [1] prune_out_channels on layer4.0.downsample.0 (Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)) => prune_out_channels on layer4.0.downsample.1 (BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)), len(idxs)=52
# [2] prune_out_channels on layer4.0.downsample.1 (BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)) => prune_out_channels on _ElementWiseOp_6(AddBackward0), len(idxs)=52
# [3] prune_out_channels on _ElementWiseOp_6(AddBackward0) => prune_out_channels on layer4.0.bn2 (BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)), len(idxs)=52
# [4] prune_out_channels on _ElementWiseOp_6(AddBackward0) => prune_out_channels on _ElementWiseOp_5(ReluBackward0), len(idxs)=52
# [5] prune_out_channels on _ElementWiseOp_5(ReluBackward0) => prune_out_channels on _ElementWiseOp_4(AddBackward0), len(idxs)=52
# [6] prune_out_channels on _ElementWiseOp_5(ReluBackward0) => prune_in_channels on layer4.1.conv1 (Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=52
# [7] prune_out_channels on _ElementWiseOp_4(AddBackward0) => prune_out_channels on layer4.1.bn2 (BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)), len(idxs)=52
# [8] prune_out_channels on _ElementWiseOp_4(AddBackward0) => prune_out_channels on _ElementWiseOp_3(ReluBackward0), len(idxs)=52
# [9] prune_out_channels on _ElementWiseOp_3(ReluBackward0) => prune_out_channels on _ElementWiseOp_2(MeanBackward1), len(idxs)=52
# [10] prune_out_channels on _ElementWiseOp_2(MeanBackward1) => prune_out_channels on _Reshape_0(), len(idxs)=52
# [11] prune_out_channels on _Reshape_0() => prune_in_channels on fc (Linear(in_features=512, out_features=1000, bias=True)), len(idxs)=52
# [12] prune_in_channels on fc (Linear(in_features=512, out_features=1000, bias=True)) => prune_out_channels on _ElementWiseOp_1(TBackward0), len(idxs)=52
# [13] prune_out_channels on layer4.1.bn2 (BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)) => prune_out_channels on layer4.1.conv2 (Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=52
# [14] prune_out_channels on layer4.0.bn2 (BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)) => prune_out_channels on layer4.0.conv2 (Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=52
# --------------------------------
#
# prune_out_channels on layer4.0.downsample.0 (Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)) => prune_out_channels on layer4.0.downsample.0 (Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False))
# [5, 11, 19, 39, 40, 41, 64, 66, 72, 87, 90, 94, 105, 123, 128, 140, 154, 175, 203, 210, 211, 224, 238, 243, 281, 299, 302, 308, 313, 314, 320, 325, 342, 344, 347, 348, 351, 355, 376, 386, 396, 408, 416, 423, 449, 454, 482, 483, 496, 501, 503, 505]
# Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
# <bound method ConvPruner.prune_out_channels of <torch_pruning.pruner.function.ConvPruner object at 0x0000020646BE8A00>>
#
# --------------------------------
#           Pruning Group
# --------------------------------
# [0] prune_out_channels on layer3.0.downsample.0 (Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)) => prune_out_channels on layer3.0.downsample.0 (Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)), len(idxs)=15
# [1] prune_out_channels on layer3.0.downsample.0 (Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)) => prune_out_channels on layer3.0.downsample.1 (BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)), len(idxs)=15
# [2] prune_out_channels on layer3.0.downsample.1 (BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)) => prune_out_channels on _ElementWiseOp_10(AddBackward0), len(idxs)=15
# [3] prune_out_channels on _ElementWiseOp_10(AddBackward0) => prune_out_channels on layer3.0.bn2 (BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)), len(idxs)=15
# [4] prune_out_channels on _ElementWiseOp_10(AddBackward0) => prune_out_channels on _ElementWiseOp_9(ReluBackward0), len(idxs)=15
# [5] prune_out_channels on _ElementWiseOp_9(ReluBackward0) => prune_out_channels on _ElementWiseOp_8(AddBackward0), len(idxs)=15
# [6] prune_out_channels on _ElementWiseOp_9(ReluBackward0) => prune_in_channels on layer3.1.conv1 (Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=15
# [7] prune_out_channels on _ElementWiseOp_8(AddBackward0) => prune_out_channels on layer3.1.bn2 (BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)), len(idxs)=15
# [8] prune_out_channels on _ElementWiseOp_8(AddBackward0) => prune_out_channels on _ElementWiseOp_7(ReluBackward0), len(idxs)=15
# [9] prune_out_channels on _ElementWiseOp_7(ReluBackward0) => prune_in_channels on layer4.0.downsample.0 (Conv2d(256, 460, kernel_size=(1, 1), stride=(2, 2), bias=False)), len(idxs)=15
# [10] prune_out_channels on _ElementWiseOp_7(ReluBackward0) => prune_in_channels on layer4.0.conv1 (Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)), len(idxs)=15
# [11] prune_out_channels on layer3.1.bn2 (BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)) => prune_out_channels on layer3.1.conv2 (Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=15
# [12] prune_out_channels on layer3.0.bn2 (BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)) => prune_out_channels on layer3.0.conv2 (Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=15
# --------------------------------
#
# prune_out_channels on layer3.0.downsample.0 (Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)) => prune_out_channels on layer3.0.downsample.0 (Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False))
# [2, 30, 44, 46, 76, 140, 157, 171, 176, 195, 208, 236, 237, 241, 249]
# Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
# <bound method ConvPruner.prune_out_channels of <torch_pruning.pruner.function.ConvPruner object at 0x0000020646BE8A00>>
#
# --------------------------------
#           Pruning Group
# --------------------------------
# [0] prune_out_channels on layer2.0.downsample.0 (Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)) => prune_out_channels on layer2.0.downsample.0 (Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)), len(idxs)=24
# [1] prune_out_channels on layer2.0.downsample.0 (Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)) => prune_out_channels on layer2.0.downsample.1 (BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)), len(idxs)=24
# [2] prune_out_channels on layer2.0.downsample.1 (BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)) => prune_out_channels on _ElementWiseOp_14(AddBackward0), len(idxs)=24
# [3] prune_out_channels on _ElementWiseOp_14(AddBackward0) => prune_out_channels on layer2.0.bn2 (BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)), len(idxs)=24
# [4] prune_out_channels on _ElementWiseOp_14(AddBackward0) => prune_out_channels on _ElementWiseOp_13(ReluBackward0), len(idxs)=24
# [5] prune_out_channels on _ElementWiseOp_13(ReluBackward0) => prune_out_channels on _ElementWiseOp_12(AddBackward0), len(idxs)=24
# [6] prune_out_channels on _ElementWiseOp_13(ReluBackward0) => prune_in_channels on layer2.1.conv1 (Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=24
# [7] prune_out_channels on _ElementWiseOp_12(AddBackward0) => prune_out_channels on layer2.1.bn2 (BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)), len(idxs)=24
# [8] prune_out_channels on _ElementWiseOp_12(AddBackward0) => prune_out_channels on _ElementWiseOp_11(ReluBackward0), len(idxs)=24
# [9] prune_out_channels on _ElementWiseOp_11(ReluBackward0) => prune_in_channels on layer3.0.downsample.0 (Conv2d(128, 241, kernel_size=(1, 1), stride=(2, 2), bias=False)), len(idxs)=24
# [10] prune_out_channels on _ElementWiseOp_11(ReluBackward0) => prune_in_channels on layer3.0.conv1 (Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)), len(idxs)=24
# [11] prune_out_channels on layer2.1.bn2 (BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)) => prune_out_channels on layer2.1.conv2 (Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=24
# [12] prune_out_channels on layer2.0.bn2 (BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)) => prune_out_channels on layer2.0.conv2 (Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=24
# --------------------------------
#
# prune_out_channels on layer2.0.downsample.0 (Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)) => prune_out_channels on layer2.0.downsample.0 (Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False))
# [1, 3, 4, 13, 16, 19, 26, 37, 38, 42, 43, 46, 50, 56, 65, 68, 70, 78, 93, 94, 97, 103, 119, 122]
# Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
# <bound method ConvPruner.prune_out_channels of <torch_pruning.pruner.function.ConvPruner object at 0x0000020646BE8A00>>
#
# --------------------------------
#           Pruning Group
# --------------------------------
# [0] prune_out_channels on conv1 (Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)) => prune_out_channels on conv1 (Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)), len(idxs)=3
# [1] prune_out_channels on conv1 (Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)) => prune_out_channels on bn1 (BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)), len(idxs)=3
# [2] prune_out_channels on bn1 (BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)) => prune_out_channels on _ElementWiseOp_20(ReluBackward0), len(idxs)=3
# [3] prune_out_channels on _ElementWiseOp_20(ReluBackward0) => prune_out_channels on _ElementWiseOp_19(MaxPool2DWithIndicesBackward0), len(idxs)=3
# [4] prune_out_channels on _ElementWiseOp_19(MaxPool2DWithIndicesBackward0) => prune_out_channels on _ElementWiseOp_18(AddBackward0), len(idxs)=3
# [5] prune_out_channels on _ElementWiseOp_19(MaxPool2DWithIndicesBackward0) => prune_in_channels on layer1.0.conv1 (Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=3
# [6] prune_out_channels on _ElementWiseOp_18(AddBackward0) => prune_out_channels on layer1.0.bn2 (BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)), len(idxs)=3
# [7] prune_out_channels on _ElementWiseOp_18(AddBackward0) => prune_out_channels on _ElementWiseOp_17(ReluBackward0), len(idxs)=3
# [8] prune_out_channels on _ElementWiseOp_17(ReluBackward0) => prune_out_channels on _ElementWiseOp_16(AddBackward0), len(idxs)=3
# [9] prune_out_channels on _ElementWiseOp_17(ReluBackward0) => prune_in_channels on layer1.1.conv1 (Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=3
# [10] prune_out_channels on _ElementWiseOp_16(AddBackward0) => prune_out_channels on layer1.1.bn2 (BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)), len(idxs)=3
# [11] prune_out_channels on _ElementWiseOp_16(AddBackward0) => prune_out_channels on _ElementWiseOp_15(ReluBackward0), len(idxs)=3
# [12] prune_out_channels on _ElementWiseOp_15(ReluBackward0) => prune_in_channels on layer2.0.downsample.0 (Conv2d(64, 104, kernel_size=(1, 1), stride=(2, 2), bias=False)), len(idxs)=3
# [13] prune_out_channels on _ElementWiseOp_15(ReluBackward0) => prune_in_channels on layer2.0.conv1 (Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)), len(idxs)=3
# [14] prune_out_channels on layer1.1.bn2 (BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)) => prune_out_channels on layer1.1.conv2 (Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=3
# [15] prune_out_channels on layer1.0.bn2 (BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)) => prune_out_channels on layer1.0.conv2 (Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=3
# --------------------------------
#
# prune_out_channels on conv1 (Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)) => prune_out_channels on conv1 (Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False))
# [2, 9, 13]
# Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
# <bound method ConvPruner.prune_out_channels of <torch_pruning.pruner.function.ConvPruner object at 0x0000020646BE8A00>>
#
# --------------------------------
#           Pruning Group
# --------------------------------
# [0] prune_out_channels on layer1.0.conv1 (Conv2d(61, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)) => prune_out_channels on layer1.0.conv1 (Conv2d(61, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=22
# [1] prune_out_channels on layer1.0.conv1 (Conv2d(61, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)) => prune_out_channels on layer1.0.bn1 (BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)), len(idxs)=22
# [2] prune_out_channels on layer1.0.bn1 (BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)) => prune_out_channels on _ElementWiseOp_21(ReluBackward0), len(idxs)=22
# [3] prune_out_channels on _ElementWiseOp_21(ReluBackward0) => prune_in_channels on layer1.0.conv2 (Conv2d(64, 61, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=22
# --------------------------------
#
# prune_out_channels on layer1.0.conv1 (Conv2d(61, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)) => prune_out_channels on layer1.0.conv1 (Conv2d(61, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False))
# [10, 11, 16, 17, 21, 23, 24, 25, 29, 30, 32, 44, 47, 48, 51, 52, 55, 56, 57, 59, 61, 62]
# Conv2d(61, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# <bound method ConvPruner.prune_out_channels of <torch_pruning.pruner.function.ConvPruner object at 0x0000020646BE8A00>>
#
# --------------------------------
#           Pruning Group
# --------------------------------
# [0] prune_out_channels on layer1.1.conv1 (Conv2d(61, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)) => prune_out_channels on layer1.1.conv1 (Conv2d(61, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=23
# [1] prune_out_channels on layer1.1.conv1 (Conv2d(61, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)) => prune_out_channels on layer1.1.bn1 (BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)), len(idxs)=23
# [2] prune_out_channels on layer1.1.bn1 (BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)) => prune_out_channels on _ElementWiseOp_22(ReluBackward0), len(idxs)=23
# [3] prune_out_channels on _ElementWiseOp_22(ReluBackward0) => prune_in_channels on layer1.1.conv2 (Conv2d(64, 61, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=23
# --------------------------------
#
# prune_out_channels on layer1.1.conv1 (Conv2d(61, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)) => prune_out_channels on layer1.1.conv1 (Conv2d(61, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False))
# [3, 6, 12, 15, 17, 18, 20, 22, 24, 26, 27, 28, 30, 33, 34, 37, 40, 42, 45, 46, 48, 53, 57]
# Conv2d(61, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# <bound method ConvPruner.prune_out_channels of <torch_pruning.pruner.function.ConvPruner object at 0x0000020646BE8A00>>
#
# --------------------------------
#           Pruning Group
# --------------------------------
# [0] prune_out_channels on layer2.0.conv1 (Conv2d(61, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)) => prune_out_channels on layer2.0.conv1 (Conv2d(61, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)), len(idxs)=14
# [1] prune_out_channels on layer2.0.conv1 (Conv2d(61, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)) => prune_out_channels on layer2.0.bn1 (BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)), len(idxs)=14
# [2] prune_out_channels on layer2.0.bn1 (BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)) => prune_out_channels on _ElementWiseOp_23(ReluBackward0), len(idxs)=14
# [3] prune_out_channels on _ElementWiseOp_23(ReluBackward0) => prune_in_channels on layer2.0.conv2 (Conv2d(128, 104, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=14
# --------------------------------
#
# prune_out_channels on layer2.0.conv1 (Conv2d(61, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)) => prune_out_channels on layer2.0.conv1 (Conv2d(61, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False))
# [8, 10, 14, 30, 33, 41, 45, 61, 62, 71, 79, 84, 85, 90]
# Conv2d(61, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
# <bound method ConvPruner.prune_out_channels of <torch_pruning.pruner.function.ConvPruner object at 0x0000020646BE8A00>>
#
# --------------------------------
#           Pruning Group
# --------------------------------
# [0] prune_out_channels on layer2.1.conv1 (Conv2d(104, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)) => prune_out_channels on layer2.1.conv1 (Conv2d(104, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=24
# [1] prune_out_channels on layer2.1.conv1 (Conv2d(104, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)) => prune_out_channels on layer2.1.bn1 (BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)), len(idxs)=24
# [2] prune_out_channels on layer2.1.bn1 (BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)) => prune_out_channels on _ElementWiseOp_24(ReluBackward0), len(idxs)=24
# [3] prune_out_channels on _ElementWiseOp_24(ReluBackward0) => prune_in_channels on layer2.1.conv2 (Conv2d(128, 104, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=24
# --------------------------------
#
# prune_out_channels on layer2.1.conv1 (Conv2d(104, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)) => prune_out_channels on layer2.1.conv1 (Conv2d(104, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False))
# [1, 4, 6, 10, 14, 27, 30, 32, 33, 35, 41, 65, 72, 80, 84, 91, 97, 106, 109, 111, 112, 113, 117, 118]
# Conv2d(104, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# <bound method ConvPruner.prune_out_channels of <torch_pruning.pruner.function.ConvPruner object at 0x0000020646BE8A00>>
#
# --------------------------------
#           Pruning Group
# --------------------------------
# [0] prune_out_channels on layer3.0.conv1 (Conv2d(104, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)) => prune_out_channels on layer3.0.conv1 (Conv2d(104, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)), len(idxs)=40
# [1] prune_out_channels on layer3.0.conv1 (Conv2d(104, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)) => prune_out_channels on layer3.0.bn1 (BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)), len(idxs)=40
# [2] prune_out_channels on layer3.0.bn1 (BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)) => prune_out_channels on _ElementWiseOp_25(ReluBackward0), len(idxs)=40
# [3] prune_out_channels on _ElementWiseOp_25(ReluBackward0) => prune_in_channels on layer3.0.conv2 (Conv2d(256, 241, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=40
# --------------------------------
#
# prune_out_channels on layer3.0.conv1 (Conv2d(104, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)) => prune_out_channels on layer3.0.conv1 (Conv2d(104, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False))
# [15, 16, 29, 40, 42, 50, 52, 54, 58, 65, 66, 86, 87, 97, 104, 117, 119, 121, 126, 129, 130, 135, 142, 144, 145, 147, 152, 159, 167, 173, 175, 176, 178, 188, 191, 192, 222, 239, 240, 248]
# Conv2d(104, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
# <bound method ConvPruner.prune_out_channels of <torch_pruning.pruner.function.ConvPruner object at 0x0000020646BE8A00>>
#
# --------------------------------
#           Pruning Group
# --------------------------------
# [0] prune_out_channels on layer3.1.conv1 (Conv2d(241, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)) => prune_out_channels on layer3.1.conv1 (Conv2d(241, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=50
# [1] prune_out_channels on layer3.1.conv1 (Conv2d(241, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)) => prune_out_channels on layer3.1.bn1 (BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)), len(idxs)=50
# [2] prune_out_channels on layer3.1.bn1 (BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)) => prune_out_channels on _ElementWiseOp_26(ReluBackward0), len(idxs)=50
# [3] prune_out_channels on _ElementWiseOp_26(ReluBackward0) => prune_in_channels on layer3.1.conv2 (Conv2d(256, 241, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=50
# --------------------------------
#
# prune_out_channels on layer3.1.conv1 (Conv2d(241, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)) => prune_out_channels on layer3.1.conv1 (Conv2d(241, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False))
# [0, 2, 8, 12, 17, 20, 26, 27, 38, 45, 49, 52, 56, 58, 60, 67, 71, 74, 84, 89, 90, 101, 104, 106, 107, 113, 116, 117, 122, 123, 127, 131, 141, 143, 152, 155, 158, 163, 171, 174, 177, 179, 187, 195, 198, 203, 210, 234, 237, 241]
# Conv2d(241, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# <bound method ConvPruner.prune_out_channels of <torch_pruning.pruner.function.ConvPruner object at 0x0000020646BE8A00>>
#
# --------------------------------
#           Pruning Group
# --------------------------------
# [0] prune_out_channels on layer4.0.conv1 (Conv2d(241, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)) => prune_out_channels on layer4.0.conv1 (Conv2d(241, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)), len(idxs)=12
# [1] prune_out_channels on layer4.0.conv1 (Conv2d(241, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)) => prune_out_channels on layer4.0.bn1 (BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)), len(idxs)=12
# [2] prune_out_channels on layer4.0.bn1 (BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)) => prune_out_channels on _ElementWiseOp_27(ReluBackward0), len(idxs)=12
# [3] prune_out_channels on _ElementWiseOp_27(ReluBackward0) => prune_in_channels on layer4.0.conv2 (Conv2d(512, 460, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=12
# --------------------------------
#
# prune_out_channels on layer4.0.conv1 (Conv2d(241, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)) => prune_out_channels on layer4.0.conv1 (Conv2d(241, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False))
# [1, 75, 80, 85, 104, 139, 142, 221, 246, 354, 411, 456]
# Conv2d(241, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
# <bound method ConvPruner.prune_out_channels of <torch_pruning.pruner.function.ConvPruner object at 0x0000020646BE8A00>>
#
# --------------------------------
#           Pruning Group
# --------------------------------
# [0] prune_out_channels on layer4.1.conv1 (Conv2d(460, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)) => prune_out_channels on layer4.1.conv1 (Conv2d(460, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=7
# [1] prune_out_channels on layer4.1.conv1 (Conv2d(460, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)) => prune_out_channels on layer4.1.bn1 (BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)), len(idxs)=7
# [2] prune_out_channels on layer4.1.bn1 (BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)) => prune_out_channels on _ElementWiseOp_28(ReluBackward0), len(idxs)=7
# [3] prune_out_channels on _ElementWiseOp_28(ReluBackward0) => prune_in_channels on layer4.1.conv2 (Conv2d(512, 460, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=7
# --------------------------------
#
# prune_out_channels on layer4.1.conv1 (Conv2d(460, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)) => prune_out_channels on layer4.1.conv1 (Conv2d(460, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False))
# [158, 160, 238, 270, 358, 469, 502]
# Conv2d(460, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# <bound method ConvPruner.prune_out_channels of <torch_pruning.pruner.function.ConvPruner object at 0x0000020646BE8A00>>
# torch.Size([1, 1000])
#   Iter 1/5, Params: 11.69 M => 9.98 M
#   Iter 1/5, MACs: 1.82 G => 1.37 G
#
# --------------------------------
#           Pruning Group
# --------------------------------
# [0] prune_out_channels on layer4.0.downsample.0 (Conv2d(241, 460, kernel_size=(1, 1), stride=(2, 2), bias=False)) => prune_out_channels on layer4.0.downsample.0 (Conv2d(241, 460, kernel_size=(1, 1), stride=(2, 2), bias=False)), len(idxs)=51
# [1] prune_out_channels on layer4.0.downsample.0 (Conv2d(241, 460, kernel_size=(1, 1), stride=(2, 2), bias=False)) => prune_out_channels on layer4.0.downsample.1 (BatchNorm2d(460, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)), len(idxs)=51
# [2] prune_out_channels on layer4.0.downsample.1 (BatchNorm2d(460, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)) => prune_out_channels on _ElementWiseOp_6(AddBackward0), len(idxs)=51
# [3] prune_out_channels on _ElementWiseOp_6(AddBackward0) => prune_out_channels on layer4.0.bn2 (BatchNorm2d(460, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)), len(idxs)=51
# [4] prune_out_channels on _ElementWiseOp_6(AddBackward0) => prune_out_channels on _ElementWiseOp_5(ReluBackward0), len(idxs)=51
# [5] prune_out_channels on _ElementWiseOp_5(ReluBackward0) => prune_out_channels on _ElementWiseOp_4(AddBackward0), len(idxs)=51
# [6] prune_out_channels on _ElementWiseOp_5(ReluBackward0) => prune_in_channels on layer4.1.conv1 (Conv2d(460, 505, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=51
# [7] prune_out_channels on _ElementWiseOp_4(AddBackward0) => prune_out_channels on layer4.1.bn2 (BatchNorm2d(460, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)), len(idxs)=51
# [8] prune_out_channels on _ElementWiseOp_4(AddBackward0) => prune_out_channels on _ElementWiseOp_3(ReluBackward0), len(idxs)=51
# [9] prune_out_channels on _ElementWiseOp_3(ReluBackward0) => prune_out_channels on _ElementWiseOp_2(MeanBackward1), len(idxs)=51
# [10] prune_out_channels on _ElementWiseOp_2(MeanBackward1) => prune_out_channels on _Reshape_0(), len(idxs)=51
# [11] prune_out_channels on _Reshape_0() => prune_in_channels on fc (Linear(in_features=460, out_features=1000, bias=True)), len(idxs)=51
# [12] prune_in_channels on fc (Linear(in_features=460, out_features=1000, bias=True)) => prune_out_channels on _ElementWiseOp_1(TBackward0), len(idxs)=51
# [13] prune_out_channels on layer4.1.bn2 (BatchNorm2d(460, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)) => prune_out_channels on layer4.1.conv2 (Conv2d(505, 460, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=51
# [14] prune_out_channels on layer4.0.bn2 (BatchNorm2d(460, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)) => prune_out_channels on layer4.0.conv2 (Conv2d(500, 460, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=51
# --------------------------------
#
# prune_out_channels on layer4.0.downsample.0 (Conv2d(241, 460, kernel_size=(1, 1), stride=(2, 2), bias=False)) => prune_out_channels on layer4.0.downsample.0 (Conv2d(241, 460, kernel_size=(1, 1), stride=(2, 2), bias=False))
# [9, 17, 30, 65, 68, 76, 79, 85, 87, 92, 99, 103, 109, 126, 134, 135, 141, 142, 170, 176, 197, 203, 212, 223, 230, 241, 244, 251, 260, 265, 273, 276, 278, 285, 296, 303, 307, 308, 316, 336, 348, 349, 356, 361, 395, 399, 405, 410, 419, 431, 434]
# Conv2d(241, 460, kernel_size=(1, 1), stride=(2, 2), bias=False)
# <bound method ConvPruner.prune_out_channels of <torch_pruning.pruner.function.ConvPruner object at 0x0000020646BE8A00>>
#
# --------------------------------
#           Pruning Group
# --------------------------------
# [0] prune_out_channels on layer3.0.downsample.0 (Conv2d(104, 241, kernel_size=(1, 1), stride=(2, 2), bias=False)) => prune_out_channels on layer3.0.downsample.0 (Conv2d(104, 241, kernel_size=(1, 1), stride=(2, 2), bias=False)), len(idxs)=19
# [1] prune_out_channels on layer3.0.downsample.0 (Conv2d(104, 241, kernel_size=(1, 1), stride=(2, 2), bias=False)) => prune_out_channels on layer3.0.downsample.1 (BatchNorm2d(241, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)), len(idxs)=19
# [2] prune_out_channels on layer3.0.downsample.1 (BatchNorm2d(241, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)) => prune_out_channels on _ElementWiseOp_10(AddBackward0), len(idxs)=19
# [3] prune_out_channels on _ElementWiseOp_10(AddBackward0) => prune_out_channels on layer3.0.bn2 (BatchNorm2d(241, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)), len(idxs)=19
# [4] prune_out_channels on _ElementWiseOp_10(AddBackward0) => prune_out_channels on _ElementWiseOp_9(ReluBackward0), len(idxs)=19
# [5] prune_out_channels on _ElementWiseOp_9(ReluBackward0) => prune_out_channels on _ElementWiseOp_8(AddBackward0), len(idxs)=19
# [6] prune_out_channels on _ElementWiseOp_9(ReluBackward0) => prune_in_channels on layer3.1.conv1 (Conv2d(241, 206, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=19
# [7] prune_out_channels on _ElementWiseOp_8(AddBackward0) => prune_out_channels on layer3.1.bn2 (BatchNorm2d(241, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)), len(idxs)=19
# [8] prune_out_channels on _ElementWiseOp_8(AddBackward0) => prune_out_channels on _ElementWiseOp_7(ReluBackward0), len(idxs)=19
# [9] prune_out_channels on _ElementWiseOp_7(ReluBackward0) => prune_in_channels on layer4.0.downsample.0 (Conv2d(241, 409, kernel_size=(1, 1), stride=(2, 2), bias=False)), len(idxs)=19
# [10] prune_out_channels on _ElementWiseOp_7(ReluBackward0) => prune_in_channels on layer4.0.conv1 (Conv2d(241, 500, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)), len(idxs)=19
# [11] prune_out_channels on layer3.1.bn2 (BatchNorm2d(241, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)) => prune_out_channels on layer3.1.conv2 (Conv2d(206, 241, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=19
# [12] prune_out_channels on layer3.0.bn2 (BatchNorm2d(241, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)) => prune_out_channels on layer3.0.conv2 (Conv2d(216, 241, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=19
# --------------------------------
#
# prune_out_channels on layer3.0.downsample.0 (Conv2d(104, 241, kernel_size=(1, 1), stride=(2, 2), bias=False)) => prune_out_channels on layer3.0.downsample.0 (Conv2d(104, 241, kernel_size=(1, 1), stride=(2, 2), bias=False))
# [2, 5, 32, 36, 41, 42, 69, 73, 76, 106, 120, 122, 145, 164, 176, 184, 220, 225, 240]
# Conv2d(104, 241, kernel_size=(1, 1), stride=(2, 2), bias=False)
# <bound method ConvPruner.prune_out_channels of <torch_pruning.pruner.function.ConvPruner object at 0x0000020646BE8A00>>
#
# --------------------------------
#           Pruning Group
# --------------------------------
# [0] prune_out_channels on layer2.0.downsample.0 (Conv2d(61, 104, kernel_size=(1, 1), stride=(2, 2), bias=False)) => prune_out_channels on layer2.0.downsample.0 (Conv2d(61, 104, kernel_size=(1, 1), stride=(2, 2), bias=False)), len(idxs)=19
# [1] prune_out_channels on layer2.0.downsample.0 (Conv2d(61, 104, kernel_size=(1, 1), stride=(2, 2), bias=False)) => prune_out_channels on layer2.0.downsample.1 (BatchNorm2d(104, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)), len(idxs)=19
# [2] prune_out_channels on layer2.0.downsample.1 (BatchNorm2d(104, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)) => prune_out_channels on _ElementWiseOp_14(AddBackward0), len(idxs)=19
# [3] prune_out_channels on _ElementWiseOp_14(AddBackward0) => prune_out_channels on layer2.0.bn2 (BatchNorm2d(104, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)), len(idxs)=19
# [4] prune_out_channels on _ElementWiseOp_14(AddBackward0) => prune_out_channels on _ElementWiseOp_13(ReluBackward0), len(idxs)=19
# [5] prune_out_channels on _ElementWiseOp_13(ReluBackward0) => prune_out_channels on _ElementWiseOp_12(AddBackward0), len(idxs)=19
# [6] prune_out_channels on _ElementWiseOp_13(ReluBackward0) => prune_in_channels on layer2.1.conv1 (Conv2d(104, 104, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=19
# [7] prune_out_channels on _ElementWiseOp_12(AddBackward0) => prune_out_channels on layer2.1.bn2 (BatchNorm2d(104, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)), len(idxs)=19
# [8] prune_out_channels on _ElementWiseOp_12(AddBackward0) => prune_out_channels on _ElementWiseOp_11(ReluBackward0), len(idxs)=19
# [9] prune_out_channels on _ElementWiseOp_11(ReluBackward0) => prune_in_channels on layer3.0.downsample.0 (Conv2d(104, 222, kernel_size=(1, 1), stride=(2, 2), bias=False)), len(idxs)=19
# [10] prune_out_channels on _ElementWiseOp_11(ReluBackward0) => prune_in_channels on layer3.0.conv1 (Conv2d(104, 216, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)), len(idxs)=19
# [11] prune_out_channels on layer2.1.bn2 (BatchNorm2d(104, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)) => prune_out_channels on layer2.1.conv2 (Conv2d(104, 104, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=19
# [12] prune_out_channels on layer2.0.bn2 (BatchNorm2d(104, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)) => prune_out_channels on layer2.0.conv2 (Conv2d(114, 104, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=19
# --------------------------------
#
# prune_out_channels on layer2.0.downsample.0 (Conv2d(61, 104, kernel_size=(1, 1), stride=(2, 2), bias=False)) => prune_out_channels on layer2.0.downsample.0 (Conv2d(61, 104, kernel_size=(1, 1), stride=(2, 2), bias=False))
# [9, 10, 11, 12, 16, 20, 21, 35, 40, 49, 62, 64, 66, 71, 76, 81, 85, 95, 99]
# Conv2d(61, 104, kernel_size=(1, 1), stride=(2, 2), bias=False)
# <bound method ConvPruner.prune_out_channels of <torch_pruning.pruner.function.ConvPruner object at 0x0000020646BE8A00>>
#
# --------------------------------
#           Pruning Group
# --------------------------------
# [0] prune_out_channels on conv1 (Conv2d(3, 61, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)) => prune_out_channels on conv1 (Conv2d(3, 61, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)), len(idxs)=3
# [1] prune_out_channels on conv1 (Conv2d(3, 61, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)) => prune_out_channels on bn1 (BatchNorm2d(61, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)), len(idxs)=3
# [2] prune_out_channels on bn1 (BatchNorm2d(61, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)) => prune_out_channels on _ElementWiseOp_20(ReluBackward0), len(idxs)=3
# [3] prune_out_channels on _ElementWiseOp_20(ReluBackward0) => prune_out_channels on _ElementWiseOp_19(MaxPool2DWithIndicesBackward0), len(idxs)=3
# [4] prune_out_channels on _ElementWiseOp_19(MaxPool2DWithIndicesBackward0) => prune_out_channels on _ElementWiseOp_18(AddBackward0), len(idxs)=3
# [5] prune_out_channels on _ElementWiseOp_19(MaxPool2DWithIndicesBackward0) => prune_in_channels on layer1.0.conv1 (Conv2d(61, 42, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=3
# [6] prune_out_channels on _ElementWiseOp_18(AddBackward0) => prune_out_channels on layer1.0.bn2 (BatchNorm2d(61, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)), len(idxs)=3
# [7] prune_out_channels on _ElementWiseOp_18(AddBackward0) => prune_out_channels on _ElementWiseOp_17(ReluBackward0), len(idxs)=3
# [8] prune_out_channels on _ElementWiseOp_17(ReluBackward0) => prune_out_channels on _ElementWiseOp_16(AddBackward0), len(idxs)=3
# [9] prune_out_channels on _ElementWiseOp_17(ReluBackward0) => prune_in_channels on layer1.1.conv1 (Conv2d(61, 41, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=3
# [10] prune_out_channels on _ElementWiseOp_16(AddBackward0) => prune_out_channels on layer1.1.bn2 (BatchNorm2d(61, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)), len(idxs)=3
# [11] prune_out_channels on _ElementWiseOp_16(AddBackward0) => prune_out_channels on _ElementWiseOp_15(ReluBackward0), len(idxs)=3
# [12] prune_out_channels on _ElementWiseOp_15(ReluBackward0) => prune_in_channels on layer2.0.downsample.0 (Conv2d(61, 85, kernel_size=(1, 1), stride=(2, 2), bias=False)), len(idxs)=3
# [13] prune_out_channels on _ElementWiseOp_15(ReluBackward0) => prune_in_channels on layer2.0.conv1 (Conv2d(61, 114, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)), len(idxs)=3
# [14] prune_out_channels on layer1.1.bn2 (BatchNorm2d(61, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)) => prune_out_channels on layer1.1.conv2 (Conv2d(41, 61, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=3
# [15] prune_out_channels on layer1.0.bn2 (BatchNorm2d(61, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)) => prune_out_channels on layer1.0.conv2 (Conv2d(42, 61, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=3
# --------------------------------
#
# prune_out_channels on conv1 (Conv2d(3, 61, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)) => prune_out_channels on conv1 (Conv2d(3, 61, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False))
# [3, 15, 32]
# Conv2d(3, 61, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
# <bound method ConvPruner.prune_out_channels of <torch_pruning.pruner.function.ConvPruner object at 0x0000020646BE8A00>>
#
# --------------------------------
#           Pruning Group
# --------------------------------
# [0] prune_out_channels on layer1.0.conv1 (Conv2d(58, 42, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)) => prune_out_channels on layer1.0.conv1 (Conv2d(58, 42, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=14
# [1] prune_out_channels on layer1.0.conv1 (Conv2d(58, 42, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)) => prune_out_channels on layer1.0.bn1 (BatchNorm2d(42, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)), len(idxs)=14
# [2] prune_out_channels on layer1.0.bn1 (BatchNorm2d(42, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)) => prune_out_channels on _ElementWiseOp_21(ReluBackward0), len(idxs)=14
# [3] prune_out_channels on _ElementWiseOp_21(ReluBackward0) => prune_in_channels on layer1.0.conv2 (Conv2d(42, 58, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=14
# --------------------------------
#
# prune_out_channels on layer1.0.conv1 (Conv2d(58, 42, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)) => prune_out_channels on layer1.0.conv1 (Conv2d(58, 42, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False))
# [4, 7, 8, 12, 14, 15, 18, 21, 24, 25, 27, 32, 37, 41]
# Conv2d(58, 42, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# <bound method ConvPruner.prune_out_channels of <torch_pruning.pruner.function.ConvPruner object at 0x0000020646BE8A00>>
#
# --------------------------------
#           Pruning Group
# --------------------------------
# [0] prune_out_channels on layer1.1.conv1 (Conv2d(58, 41, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)) => prune_out_channels on layer1.1.conv1 (Conv2d(58, 41, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=16
# [1] prune_out_channels on layer1.1.conv1 (Conv2d(58, 41, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)) => prune_out_channels on layer1.1.bn1 (BatchNorm2d(41, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)), len(idxs)=16
# [2] prune_out_channels on layer1.1.bn1 (BatchNorm2d(41, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)) => prune_out_channels on _ElementWiseOp_22(ReluBackward0), len(idxs)=16
# [3] prune_out_channels on _ElementWiseOp_22(ReluBackward0) => prune_in_channels on layer1.1.conv2 (Conv2d(41, 58, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=16
# --------------------------------
#
# prune_out_channels on layer1.1.conv1 (Conv2d(58, 41, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)) => prune_out_channels on layer1.1.conv1 (Conv2d(58, 41, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False))
# [0, 2, 3, 6, 13, 15, 19, 23, 24, 26, 34, 35, 37, 38, 39, 40]
# Conv2d(58, 41, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# <bound method ConvPruner.prune_out_channels of <torch_pruning.pruner.function.ConvPruner object at 0x0000020646BE8A00>>
#
# --------------------------------
#           Pruning Group
# --------------------------------
# [0] prune_out_channels on layer2.0.conv1 (Conv2d(58, 114, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)) => prune_out_channels on layer2.0.conv1 (Conv2d(58, 114, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)), len(idxs)=17
# [1] prune_out_channels on layer2.0.conv1 (Conv2d(58, 114, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)) => prune_out_channels on layer2.0.bn1 (BatchNorm2d(114, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)), len(idxs)=17
# [2] prune_out_channels on layer2.0.bn1 (BatchNorm2d(114, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)) => prune_out_channels on _ElementWiseOp_23(ReluBackward0), len(idxs)=17
# [3] prune_out_channels on _ElementWiseOp_23(ReluBackward0) => prune_in_channels on layer2.0.conv2 (Conv2d(114, 85, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=17
# --------------------------------
#
# prune_out_channels on layer2.0.conv1 (Conv2d(58, 114, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)) => prune_out_channels on layer2.0.conv1 (Conv2d(58, 114, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False))
# [4, 6, 9, 35, 36, 38, 40, 45, 51, 52, 53, 55, 68, 84, 93, 100, 104]
# Conv2d(58, 114, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
# <bound method ConvPruner.prune_out_channels of <torch_pruning.pruner.function.ConvPruner object at 0x0000020646BE8A00>>
#
# --------------------------------
#           Pruning Group
# --------------------------------
# [0] prune_out_channels on layer2.1.conv1 (Conv2d(85, 104, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)) => prune_out_channels on layer2.1.conv1 (Conv2d(85, 104, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=22
# [1] prune_out_channels on layer2.1.conv1 (Conv2d(85, 104, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)) => prune_out_channels on layer2.1.bn1 (BatchNorm2d(104, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)), len(idxs)=22
# [2] prune_out_channels on layer2.1.bn1 (BatchNorm2d(104, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)) => prune_out_channels on _ElementWiseOp_24(ReluBackward0), len(idxs)=22
# [3] prune_out_channels on _ElementWiseOp_24(ReluBackward0) => prune_in_channels on layer2.1.conv2 (Conv2d(104, 85, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=22
# --------------------------------
#
# prune_out_channels on layer2.1.conv1 (Conv2d(85, 104, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)) => prune_out_channels on layer2.1.conv1 (Conv2d(85, 104, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False))
# [1, 4, 8, 9, 14, 18, 21, 22, 28, 33, 35, 36, 43, 52, 55, 57, 67, 71, 80, 83, 84, 87]
# Conv2d(85, 104, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# <bound method ConvPruner.prune_out_channels of <torch_pruning.pruner.function.ConvPruner object at 0x0000020646BE8A00>>
#
# --------------------------------
#           Pruning Group
# --------------------------------
# [0] prune_out_channels on layer3.0.conv1 (Conv2d(85, 216, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)) => prune_out_channels on layer3.0.conv1 (Conv2d(85, 216, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)), len(idxs)=54
# [1] prune_out_channels on layer3.0.conv1 (Conv2d(85, 216, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)) => prune_out_channels on layer3.0.bn1 (BatchNorm2d(216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)), len(idxs)=54
# [2] prune_out_channels on layer3.0.bn1 (BatchNorm2d(216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)) => prune_out_channels on _ElementWiseOp_25(ReluBackward0), len(idxs)=54
# [3] prune_out_channels on _ElementWiseOp_25(ReluBackward0) => prune_in_channels on layer3.0.conv2 (Conv2d(216, 222, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=54
# --------------------------------
#
# prune_out_channels on layer3.0.conv1 (Conv2d(85, 216, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)) => prune_out_channels on layer3.0.conv1 (Conv2d(85, 216, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False))
# [6, 7, 18, 19, 20, 22, 23, 24, 28, 30, 33, 36, 39, 43, 48, 61, 65, 69, 73, 87, 88, 89, 99, 102, 105, 107, 112, 126, 130, 138, 139, 140, 144, 149, 150, 152, 155, 158, 167, 168, 173, 179, 180, 189, 191, 194, 196, 198, 201, 203, 204, 206, 212, 213]
# Conv2d(85, 216, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
# <bound method ConvPruner.prune_out_channels of <torch_pruning.pruner.function.ConvPruner object at 0x0000020646BE8A00>>
#
# --------------------------------
#           Pruning Group
# --------------------------------
# [0] prune_out_channels on layer3.1.conv1 (Conv2d(222, 206, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)) => prune_out_channels on layer3.1.conv1 (Conv2d(222, 206, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=38
# [1] prune_out_channels on layer3.1.conv1 (Conv2d(222, 206, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)) => prune_out_channels on layer3.1.bn1 (BatchNorm2d(206, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)), len(idxs)=38
# ...
# [1] prune_out_channels on conv1 (Conv2d(3, 53, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)) => prune_out_channels on bn1 (BatchNorm2d(53, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)), len(idxs)=2
# [2] prune_out_channels on bn1 (BatchNorm2d(53, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)) => prune_out_channels on _ElementWiseOp_20(ReluBackward0), len(idxs)=2
# [3] prune_out_channels on _ElementWiseOp_20(ReluBackward0) => prune_out_channels on _ElementWiseOp_19(MaxPool2DWithIndicesBackward0), len(idxs)=2
# [4] prune_out_channels on _ElementWiseOp_19(MaxPool2DWithIndicesBackward0) => prune_out_channels on _ElementWiseOp_18(AddBackward0), len(idxs)=2
# [5] prune_out_channels on _ElementWiseOp_19(MaxPool2DWithIndicesBackward0) => prune_in_channels on layer1.0.conv1 (Conv2d(53, 11, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=2
# [6] prune_out_channels on _ElementWiseOp_18(AddBackward0) => prune_out_channels on layer1.0.bn2 (BatchNorm2d(53, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)), len(idxs)=2
# [7] prune_out_channels on _ElementWiseOp_18(AddBackward0) => prune_out_channels on _ElementWiseOp_17(ReluBackward0), len(idxs)=2
# [8] prune_out_channels on _ElementWiseOp_17(ReluBackward0) => prune_out_channels on _ElementWiseOp_16(AddBackward0), len(idxs)=2
# [9] prune_out_channels on _ElementWiseOp_17(ReluBackward0) => prune_in_channels on layer1.1.conv1 (Conv2d(53, 7, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=2
# [10] prune_out_channels on _ElementWiseOp_16(AddBackward0) => prune_out_channels on layer1.1.bn2 (BatchNorm2d(53, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)), len(idxs)=2
# [11] prune_out_channels on _ElementWiseOp_16(AddBackward0) => prune_out_channels on _ElementWiseOp_15(ReluBackward0), len(idxs)=2
# [12] prune_out_channels on _ElementWiseOp_15(ReluBackward0) => prune_in_channels on layer2.0.downsample.0 (Conv2d(53, 37, kernel_size=(1, 1), stride=(2, 2), bias=False)), len(idxs)=2
# [13] prune_out_channels on _ElementWiseOp_15(ReluBackward0) => prune_in_channels on layer2.0.conv1 (Conv2d(53, 67, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)), len(idxs)=2
# [14] prune_out_channels on layer1.1.bn2 (BatchNorm2d(53, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)) => prune_out_channels on layer1.1.conv2 (Conv2d(7, 53, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=2
# [15] prune_out_channels on layer1.0.bn2 (BatchNorm2d(53, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)) => prune_out_channels on layer1.0.conv2 (Conv2d(11, 53, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=2
# --------------------------------
#
# prune_out_channels on conv1 (Conv2d(3, 53, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)) => prune_out_channels on conv1 (Conv2d(3, 53, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False))
# [38, 50]
# Conv2d(3, 53, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
# <bound method ConvPruner.prune_out_channels of <torch_pruning.pruner.function.ConvPruner object at 0x0000020646BE8A00>>
#
# --------------------------------
#           Pruning Group
# --------------------------------
# [0] prune_out_channels on layer1.0.conv1 (Conv2d(51, 11, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)) => prune_out_channels on layer1.0.conv1 (Conv2d(51, 11, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=5
# [1] prune_out_channels on layer1.0.conv1 (Conv2d(51, 11, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)) => prune_out_channels on layer1.0.bn1 (BatchNorm2d(11, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)), len(idxs)=5
# [2] prune_out_channels on layer1.0.bn1 (BatchNorm2d(11, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)) => prune_out_channels on _ElementWiseOp_21(ReluBackward0), len(idxs)=5
# [3] prune_out_channels on _ElementWiseOp_21(ReluBackward0) => prune_in_channels on layer1.0.conv2 (Conv2d(11, 51, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=5
# --------------------------------
#
# prune_out_channels on layer1.0.conv1 (Conv2d(51, 11, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)) => prune_out_channels on layer1.0.conv1 (Conv2d(51, 11, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False))
# [2, 4, 6, 8, 9]
# Conv2d(51, 11, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# <bound method ConvPruner.prune_out_channels of <torch_pruning.pruner.function.ConvPruner object at 0x0000020646BE8A00>>
#
# --------------------------------
#           Pruning Group
# --------------------------------
# [0] prune_out_channels on layer1.1.conv1 (Conv2d(51, 7, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)) => prune_out_channels on layer1.1.conv1 (Conv2d(51, 7, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=4
# [1] prune_out_channels on layer1.1.conv1 (Conv2d(51, 7, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)) => prune_out_channels on layer1.1.bn1 (BatchNorm2d(7, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)), len(idxs)=4
# [2] prune_out_channels on layer1.1.bn1 (BatchNorm2d(7, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)) => prune_out_channels on _ElementWiseOp_22(ReluBackward0), len(idxs)=4
# [3] prune_out_channels on _ElementWiseOp_22(ReluBackward0) => prune_in_channels on layer1.1.conv2 (Conv2d(7, 51, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=4
# --------------------------------
#
# prune_out_channels on layer1.1.conv1 (Conv2d(51, 7, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)) => prune_out_channels on layer1.1.conv1 (Conv2d(51, 7, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False))
# [2, 3, 4, 5]
# Conv2d(51, 7, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# <bound method ConvPruner.prune_out_channels of <torch_pruning.pruner.function.ConvPruner object at 0x0000020646BE8A00>>
#
# --------------------------------
#           Pruning Group
# --------------------------------
# [0] prune_out_channels on layer2.0.conv1 (Conv2d(51, 67, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)) => prune_out_channels on layer2.0.conv1 (Conv2d(51, 67, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)), len(idxs)=22
# [1] prune_out_channels on layer2.0.conv1 (Conv2d(51, 67, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)) => prune_out_channels on layer2.0.bn1 (BatchNorm2d(67, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)), len(idxs)=22
# [2] prune_out_channels on layer2.0.bn1 (BatchNorm2d(67, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)) => prune_out_channels on _ElementWiseOp_23(ReluBackward0), len(idxs)=22
# [3] prune_out_channels on _ElementWiseOp_23(ReluBackward0) => prune_in_channels on layer2.0.conv2 (Conv2d(67, 37, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=22
# --------------------------------
#
# prune_out_channels on layer2.0.conv1 (Conv2d(51, 67, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)) => prune_out_channels on layer2.0.conv1 (Conv2d(51, 67, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False))
# [0, 6, 9, 11, 13, 20, 24, 27, 32, 35, 36, 44, 47, 50, 51, 52, 53, 54, 56, 61, 63, 64]
# Conv2d(51, 67, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
# <bound method ConvPruner.prune_out_channels of <torch_pruning.pruner.function.ConvPruner object at 0x0000020646BE8A00>>
#
# --------------------------------
#           Pruning Group
# --------------------------------
# [0] prune_out_channels on layer2.1.conv1 (Conv2d(37, 46, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)) => prune_out_channels on layer2.1.conv1 (Conv2d(37, 46, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=15
# [1] prune_out_channels on layer2.1.conv1 (Conv2d(37, 46, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)) => prune_out_channels on layer2.1.bn1 (BatchNorm2d(46, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)), len(idxs)=15
# [2] prune_out_channels on layer2.1.bn1 (BatchNorm2d(46, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)) => prune_out_channels on _ElementWiseOp_24(ReluBackward0), len(idxs)=15
# [3] prune_out_channels on _ElementWiseOp_24(ReluBackward0) => prune_in_channels on layer2.1.conv2 (Conv2d(46, 37, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=15
# --------------------------------
#
# prune_out_channels on layer2.1.conv1 (Conv2d(37, 46, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)) => prune_out_channels on layer2.1.conv1 (Conv2d(37, 46, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False))
# [1, 8, 9, 12, 15, 16, 18, 22, 27, 30, 35, 36, 37, 42, 45]
# Conv2d(37, 46, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# <bound method ConvPruner.prune_out_channels of <torch_pruning.pruner.function.ConvPruner object at 0x0000020646BE8A00>>
#
# --------------------------------
#           Pruning Group
# --------------------------------
# [0] prune_out_channels on layer3.0.conv1 (Conv2d(37, 63, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)) => prune_out_channels on layer3.0.conv1 (Conv2d(37, 63, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)), len(idxs)=30
# [1] prune_out_channels on layer3.0.conv1 (Conv2d(37, 63, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)) => prune_out_channels on layer3.0.bn1 (BatchNorm2d(63, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)), len(idxs)=30
# [2] prune_out_channels on layer3.0.bn1 (BatchNorm2d(63, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)) => prune_out_channels on _ElementWiseOp_25(ReluBackward0), len(idxs)=30
# [3] prune_out_channels on _ElementWiseOp_25(ReluBackward0) => prune_in_channels on layer3.0.conv2 (Conv2d(63, 155, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=30
# --------------------------------
#
# prune_out_channels on layer3.0.conv1 (Conv2d(37, 63, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)) => prune_out_channels on layer3.0.conv1 (Conv2d(37, 63, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False))
# [0, 2, 3, 4, 7, 9, 10, 14, 15, 19, 22, 24, 26, 28, 29, 30, 34, 35, 36, 39, 40, 42, 43, 47, 50, 51, 52, 57, 59, 61]
# Conv2d(37, 63, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
# <bound method ConvPruner.prune_out_channels of <torch_pruning.pruner.function.ConvPruner object at 0x0000020646BE8A00>>
#
# --------------------------------
#           Pruning Group
# --------------------------------
# [0] prune_out_channels on layer3.1.conv1 (Conv2d(155, 105, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)) => prune_out_channels on layer3.1.conv1 (Conv2d(155, 105, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=27
# [1] prune_out_channels on layer3.1.conv1 (Conv2d(155, 105, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)) => prune_out_channels on layer3.1.bn1 (BatchNorm2d(105, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)), len(idxs)=27
# [2] prune_out_channels on layer3.1.bn1 (BatchNorm2d(105, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)) => prune_out_channels on _ElementWiseOp_26(ReluBackward0), len(idxs)=27
# [3] prune_out_channels on _ElementWiseOp_26(ReluBackward0) => prune_in_channels on layer3.1.conv2 (Conv2d(105, 155, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=27
# --------------------------------
#
# prune_out_channels on layer3.1.conv1 (Conv2d(155, 105, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)) => prune_out_channels on layer3.1.conv1 (Conv2d(155, 105, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False))
# [0, 6, 10, 11, 16, 20, 25, 27, 29, 35, 36, 39, 44, 47, 56, 59, 69, 75, 76, 79, 85, 90, 91, 92, 93, 96, 97]
# Conv2d(155, 105, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# <bound method ConvPruner.prune_out_channels of <torch_pruning.pruner.function.ConvPruner object at 0x0000020646BE8A00>>
#
# --------------------------------
#           Pruning Group
# --------------------------------
# [0] prune_out_channels on layer4.0.conv1 (Conv2d(155, 414, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)) => prune_out_channels on layer4.0.conv1 (Conv2d(155, 414, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)), len(idxs)=59
# [1] prune_out_channels on layer4.0.conv1 (Conv2d(155, 414, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)) => prune_out_channels on layer4.0.bn1 (BatchNorm2d(414, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)), len(idxs)=59
# [2] prune_out_channels on layer4.0.bn1 (BatchNorm2d(414, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)) => prune_out_channels on _ElementWiseOp_27(ReluBackward0), len(idxs)=59
# [3] prune_out_channels on _ElementWiseOp_27(ReluBackward0) => prune_in_channels on layer4.0.conv2 (Conv2d(414, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=59
# --------------------------------
#
# prune_out_channels on layer4.0.conv1 (Conv2d(155, 414, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)) => prune_out_channels on layer4.0.conv1 (Conv2d(155, 414, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False))
# [2, 22, 23, 25, 31, 32, 36, 41, 42, 46, 72, 75, 80, 86, 90, 91, 103, 107, 110, 115, 144, 145, 154, 168, 170, 173, 175, 176, 192, 196, 211, 213, 222, 231, 235, 236, 240, 244, 247, 267, 273, 274, 282, 328, 336, 339, 348, 350, 351, 352, 358, 363, 373, 376, 377, 390, 397, 408, 412]
# Conv2d(155, 414, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
# <bound method ConvPruner.prune_out_channels of <torch_pruning.pruner.function.ConvPruner object at 0x0000020646BE8A00>>
#
# --------------------------------
#           Pruning Group
# --------------------------------
# [0] prune_out_channels on layer4.1.conv1 (Conv2d(256, 439, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)) => prune_out_channels on layer4.1.conv1 (Conv2d(256, 439, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=30
# [1] prune_out_channels on layer4.1.conv1 (Conv2d(256, 439, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)) => prune_out_channels on layer4.1.bn1 (BatchNorm2d(439, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)), len(idxs)=30
# [2] prune_out_channels on layer4.1.bn1 (BatchNorm2d(439, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)) => prune_out_channels on _ElementWiseOp_28(ReluBackward0), len(idxs)=30
# [3] prune_out_channels on _ElementWiseOp_28(ReluBackward0) => prune_in_channels on layer4.1.conv2 (Conv2d(439, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)), len(idxs)=30
# --------------------------------
#
# prune_out_channels on layer4.1.conv1 (Conv2d(256, 439, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)) => prune_out_channels on layer4.1.conv1 (Conv2d(256, 439, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False))
# [2, 9, 17, 35, 49, 56, 64, 122, 153, 158, 179, 185, 188, 194, 218, 244, 262, 264, 267, 272, 279, 290, 291, 299, 307, 340, 392, 398, 405, 429]
# Conv2d(256, 439, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# <bound method ConvPruner.prune_out_channels of <torch_pruning.pruner.function.ConvPruner object at 0x0000020646BE8A00>>
# torch.Size([1, 1000])
#   Iter 5/5, Params: 11.69 M => 3.85 M
#   Iter 5/5, MACs: 1.82 G => 0.38 G

# %% [markdown]
# ### 底层剪枝函数
#
# 在 Torch-Pruning 中，我们提供了一系列低级剪枝函数，这些函数仅剪枝单个层或模块。要手动剪枝 ResNet-18 的 model.conv1 ，剪枝流程应如下所示：

# %%
model = resnet18(pretrained=True)
example_inputs = torch.randn(1, 3, 224, 224)

# 0. importance criterion for parameter selections
# 重要性准则，在这里我们计算分组权重的 L2 范数作为重要性评分。
imp = tp.importance.MagnitudeImportance(p=2, group_reduction="mean")

# 1. ignore some layers that should not be pruned, e.g., the final classifier layer.
ignored_layers = []
for name, module in model.named_modules():
    if isinstance(module, torch.nn.Linear) and module.out_features == 1000:
        ignored_layers.append(module)  # DO NOT prune the final classifier!
        print(name)

# 2. Pruner initialization
# 剪枝初始化
iterative_steps = 5  # You can prune your model to the target pruning ratio iteratively.
pruner = tp.pruner.MagnitudePruner(
    model,
    example_inputs,
    isomorphic=True,
    global_pruning=True,  # If False, a uniform ratio will be assigned to different layers.
    importance=imp,  # importance criterion for parameter selection
    iterative_steps=iterative_steps,  # the number of iterations to achieve target ratio
    pruning_ratio=0.5,  # remove 50% channels, ResNet18 = {64, 128, 256, 512} => ResNet18_Half = {32, 64, 128, 256}
    ignored_layers=ignored_layers,
    pruning_ratio_dict={
        model.conv1: 0.2,
    },
)

tp.prune_conv_out_channels(model.conv1, idxs=[2, 6, 9])

# 手动修改后续层的通道
tp.prune_batchnorm_out_channels( model.bn1, idxs=[2,6,9] )
tp.prune_conv_in_channels( model.layer1[0].conv1, idxs=[2,6,9] )
# tp.prune_conv_out_channels( model.layer1[0].conv1, idxs=[2,6,9] )
# tp.prune_batchnorm_out_channels( model.layer1[0].bn1, idxs=[2,6,9] )
# tp.prune_conv_in_channels( model.layer1[0].conv2, idxs=[2,6,9] )

print(model)
print(model(example_inputs).shape)

# %% [markdown]
# ### 加载和保存
# 我们介绍一种利用 pruning_history 来存储和读取剪枝后模型的方法，该方法与PyTorch采用的state_dict非常相似

# %%
model = resnet18(pretrained=True)
example_inputs = torch.randn(1, 3, 224, 224)

# print(model)
# Global metrics

imp = tp.importance.MagnitudeImportance(p=2)

ignored_layers = []
# DO NOT prune the final classifier!
for m in model.modules():
    if isinstance(m, torch.nn.Linear) and m.out_features == 1000:
        ignored_layers.append(m)

iterative_steps = 5
pruner = tp.pruner.MagnitudePruner(
    model,
    example_inputs,
    importance=imp,
    iterative_steps=iterative_steps,
    pruning_ratio=0.5, 
    ignored_layers=ignored_layers,
)

base_macs, base_nparams = tp.utils.count_ops_and_params(model, example_inputs)
for i in range(iterative_steps):
    pruner.step()
    macs, nparams = tp.utils.count_ops_and_params(model, example_inputs)
    # print(model)
    # print(model(example_inputs).shape)
    print(
        "  Iter %d/%d, Params: %.2f M => %.2f M"
        % (i + 1, iterative_steps, base_nparams / 1e6, nparams / 1e6)
    )
    print(
        "  Iter %d/%d, MACs: %.2f G => %.2f G"
        % (i + 1, iterative_steps, base_macs / 1e9, macs / 1e9)
    )

state_dict = {
    "model": model.state_dict(),
    "pruning": pruner.pruning_history(),
}

print(pruner.pruning_history())

torch.save(state_dict, "pruned_model.pth")


# Create a new model and pruner
model = resnet18(pretrained=True)

# 构建模型关系依赖图
DG = tp.DependencyGraph().build_dependency(model, example_inputs)
# 读取权重
state_dict = torch.load("pruned_model.pth")
# 加载剪枝历史
DG.load_pruning_history(state_dict["pruning"])
# 加载权重
model.load_state_dict(state_dict["model"])
# print(model)
# Out:
#   Iter 1/5, Params: 11.69 M => 9.48 M
#   Iter 1/5, MACs: 1.82 G => 1.47 G
#   Iter 2/5, Params: 11.69 M => 7.53 M
#   Iter 2/5, MACs: 1.82 G => 1.18 G
#   Iter 3/5, Params: 11.69 M => 5.82 M
#   Iter 3/5, MACs: 1.82 G => 0.91 G
#   Iter 4/5, Params: 11.69 M => 4.32 M
#   Iter 4/5, MACs: 1.82 G => 0.68 G
#   Iter 5/5, Params: 11.69 M => 3.06 M
#   Iter 5/5, MACs: 1.82 G => 0.49 G
# [['layer4.0.downsample.0', True, [5, 11, 19, 39, 40, 41, 64, 66, 72, 87, 90, 94, 105, 123, 128, 140, 154, 175, 203, 210, 211, 224, 238, 243, 281, 299, 302, 308, 313, 314, 320, 325, 342, 344, 347, 348, 351, 355, 376, 386, 396, 408, 416, 423, 449, 454, 482, 483, 496, 501, 503, 505]], ['layer3.0.downsample.0', True, [2, 30, 34, 38, 43, 44, 46, 76, 81, 125, 140, 157, 171, 172, 176, 185, 193, 195, 208, 231, 236, 237, 238, 241, 249, 255]], ['layer2.0.downsample.0', True, [1, 3, 26, 42, 43, 46, 56, 65, 68, 78, 93, 97, 103]], ['conv1', True, [2, 4, 9, 13, 18, 35, 36]], ['layer1.0.conv1', True, [11, 17, 29, 30, 44, 56, 62]], ['layer1.1.conv1', True, [17, 20, 24, 28, 30, 42, 46]], ['layer2.0.conv1', True, [8, 14, 30, 33, 41, 45, 61, 62, 71, 79, 84, 85, 90]], ['layer2.1.conv1', True, [1, 6, 10, 27, 32, 33, 65, 80, 84, 97, 111, 113, 118]], ['layer3.0.conv1', True, [16, 29, 42, 54, 58, 65, 87, 104, 117, 119, 126, 142, 144, 145, 152, 167, 173, 175, 176, 188, 191, 192, 222, 239, 240, 248]], ['layer3.1.conv1', True, [2, 20, 26, 45, 52, 56, 58, 67, 71, 74, 89, 90, 101, 106, 113, 117, 123, 127, 141, 143, 158, 171, 187, 195, 203, 234]], ['layer4.0.conv1', True, [1, 32, 42, 55, 64, 73, 75, 80, 84, 85, 87, 91, 104, 112, 136, 137, 139, 142, 145, 148, 170, 171, 179, 182, 221, 228, 239, 240, 246, 256, 280, 291, 295, 303, 315, 346, 353, 354, 370, 372, 400, 409, 411, 415, 448, 450, 456, 457, 478, 485, 491, 504]], ['layer4.1.conv1', True, [8, 21, 25, 38, 42, 70, 75, 112, 119, 120, 124, 126, 130, 132, 146, 148, 151, 158, 160, 166, 170, 172, 178, 186, 237, 238, 249, 254, 270, 296, 303, 305, 322, 323, 327, 330, 348, 358, 365, 370, 375, 413, 414, 416, 434, 435, 450, 454, 469, 485, 502, 511]], ['layer4.0.downsample.0', True, [9, 17, 30, 48, 68, 79, 85, 87, 92, 99, 103, 109, 126, 134, 135, 141, 142, 149, 170, 176, 197, 203, 212, 223, 241, 244, 251, 260, 265, 273, 276, 278, 287, 296, 303, 307, 308, 316, 325, 336, 348, 349, 356, 361, 395, 399, 405, 410, 419, 431, 434]], ['layer3.0.downsample.0', True, [2, 5, 23, 29, 38, 39, 50, 66, 70, 71, 73, 93, 102, 106, 110, 117, 124, 128, 140, 145, 148, 177, 184, 192, 208, 215]], ['layer2.0.downsample.0', True, [2, 11, 13, 14, 17, 25, 34, 44, 61, 74, 83, 106, 109]], ['conv1', True, [5, 22, 29, 30, 47, 55]], ['layer1.0.conv1', True, [21, 23, 28, 50, 53, 55]], ['layer1.1.conv1', True, [3, 12, 20, 23, 32, 50]], ['layer2.0.conv1', True, [4, 6, 9, 36, 37, 39, 41, 46, 53, 54, 56, 94, 101]], ['layer2.1.conv1', True, [3, 5, 24, 26, 32, 35, 65, 77, 82, 96, 99, 101, 105]], ['layer3.0.conv1', True, [15, 19, 23, 25, 34, 37, 38, 47, 49, 60, 66, 70, 80, 90, 111, 113, 118, 119, 124, 142, 144, 159, 164, 182, 208, 218]], ['layer3.1.conv1', True, [0, 7, 11, 15, 16, 24, 35, 45, 53, 73, 74, 91, 101, 106, 113, 135, 142, 155, 157, 174, 185, 201, 207, 211, 215, 225]], ['layer4.0.conv1', True, [24, 26, 36, 44, 47, 48, 50, 70, 74, 83, 84, 101, 110, 111, 126, 129, 133, 162, 195, 201, 203, 205, 222, 232, 239, 252, 258, 259, 260, 267, 277, 279, 284, 285, 299, 302, 309, 319, 335, 337, 359, 369, 377, 380, 389, 404, 407, 412, 415, 442, 448]], ['layer4.1.conv1', True, [2, 5, 34, 38, 58, 59, 60, 62, 82, 92, 102, 111, 127, 134, 158, 170, 192, 198, 203, 216, 219, 225, 261, 262, 272, 281, 282, 283, 297, 300, 301, 303, 310, 318, 336, 338, 343, 348, 352, 362, 378, 380, 389, 398, 399, 403, 417, 419, 444, 449, 453]], ['layer4.0.downsample.0', True, [2, 15, 22, 25, 32, 43, 59, 61, 64, 71, 77, 78, 89, 95, 106, 112, 134, 136, 143, 147, 148, 160, 161, 169, 172, 180, 186, 194, 200, 206, 214, 223, 226, 228, 231, 237, 253, 269, 270, 278, 283, 288, 298, 320, 326, 327, 333, 340, 350, 377, 405]], ['layer3.0.downsample.0', True, [1, 2, 8, 29, 31, 37, 41, 48, 51, 59, 63, 84, 93, 104, 111, 113, 114, 117, 119, 176, 187, 188, 190, 193, 200]], ['layer2.0.downsample.0', True, [9, 10, 11, 19, 28, 34, 39, 63, 69, 74, 79, 80, 97]], ['conv1', True, [8, 11, 12, 25, 27, 37, 49]], ['layer1.0.conv1', True, [10, 21, 39, 40, 43, 44, 47]], ['layer1.1.conv1', True, [5, 15, 24, 25, 30, 36, 4 ...
# <All keys matched successfully>
